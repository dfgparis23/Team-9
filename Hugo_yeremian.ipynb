# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlrd in /opt/tljh/user/lib/python3.7/site-packages (2.0.1)

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /opt/tljh/user/lib/python3.7/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/tljh/user/lib/python3.7/site-packages (from openpyxl) (1.1.0)

# %%
# !pip install

# %%
Business_account = pd.read_excel("shared_data_read_only/Business Account.xlsx")
Consumer_price_index = pd.read_excel("shared_data_read_only/consumer_price_index.xlsx")
Contacts = pd.read_excel("shared_data_read_only/Contacts.xlsx")
Data_dictionary = pd.read_excel("shared_data_read_only/Data dictionary.xlsx")
Invoice_and_opportunities = pd.read_excel("shared_data_read_only/Invoice and Opportunities.xlsx")
Non_stock_items = pd.read_excel("shared_data_read_only/Non-Stock Items.xlsx")
Items_and_opportunities = pd.read_excel("shared_data_read_only/Items and Opportunities.xlsx")
Opportunities = pd.read_excel("shared_data_read_only/Opportunities.xlsx")

# %%
Data_dictionary
# Out:
#            Business Account                  Unnamed: 1  \
# 0    Business Account table                         NaN
# 1                   Columns                    Examples
# 2          Business Account                      C00011
# 3           Customer Status                      Active
# 4                      Type                    Customer
# 5              Partner type                     Partner
# 6                     Class                     01SIEGE
# 7                Class Name                Headquarters
# 8           Activity sector  HOTEL - CATERING - TOURISM
# 9   Parent Business Account                         NaN
# 10               Owner Name                          37
# 11           Follow-up with                           6
# 12              Postal Code                       92445
# 13                     City         ISSY-LES-MOULINEAUX
# 14                    State                         NaN
# 15               Country ID                          FR
# 16             Country Name                      France
# 17               Created On  2021-02-02 15:35:15.180000
# 18         Last Modified On  2023-09-27 15:06:45.433000
# 19                      NaN                         NaN
# 20                      NaN                         NaN
# 21                      NaN                         NaN
# 22                      NaN                         NaN
# 23                      NaN                         NaN
# 24                      NaN                         NaN
# 25                      NaN                         NaN
# 26                      NaN                         NaN
# 27                      NaN                         NaN
# 28                      NaN                         NaN
# 29                      NaN                         NaN
# 30                      NaN                         NaN
# 31                      NaN                         NaN
# 32                      NaN                         NaN
# 33                      NaN                         NaN
# 34                      NaN                         NaN
# 35                      NaN                         NaN
# 36                      NaN                         NaN
# 37                      NaN                         NaN
# 38                      NaN                         NaN
# 39                      NaN                         NaN
# 40                      NaN                         NaN
# 41                      NaN                         NaN
# 42                      NaN                         NaN
# 43                      NaN                         NaN
# 44                      NaN                         NaN
#
#                                            Unnamed: 2  Unnamed: 3  \
# 0                                                 NaN         NaN
# 1                                         Description         NaN
# 2                                 Business Account ID         NaN
# 3                                              Status         NaN
# 4   The Business account can be also Customer if i...         NaN
# 5                       Type given by the fundraisers         NaN
# 6                    Class ID of the business account         NaN
# 7                 Class Name given by the fundraisers         NaN
# 8                                     Activity sector         NaN
# 9                             Parent Business Account         NaN
# 10  Main fundraiser in charge of the business account         NaN
# 11  Second fundraiser in charge of the business ac...         NaN
# 12                Postal Code of the Business Account         NaN
# 13                       City of the Business Account         NaN
# 14                      State of the Business Account         NaN
# 15                                         Country ID         NaN
# 16               Country Name of the Business Account         NaN
# 17                                         Created On         NaN
# 18                                   Last Modified On         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         NaN
# 32                                                NaN         NaN
# 33                                                NaN         NaN
# 34                                                NaN         NaN
# 35                                                NaN         NaN
# 36                                                NaN         NaN
# 37                                                NaN         NaN
# 38                                                NaN         NaN
# 39                                                NaN         NaN
# 40                                                NaN         NaN
# 41                                                NaN         NaN
# 42                                                NaN         NaN
# 43                                                NaN         NaN
# 44                                                NaN         NaN
#
#                  Contact                                         Unnamed: 5  \
# 0          Contact table                                                NaN
# 1                Columns                                           Examples
# 2              ContactID                                              35976
# 3                 Active                                               True
# 4       Business Account                                             C00434
# 5                  Class                                            04FONDA
# 6             Class Name                                         Foundation
# 7   Financing preference  Sponsorship, Gala New York, Jogg dans la ville...
# 8                  Owner                                                 26
# 9         Follow-up with                                                 19
# 10           Postal Code                                              10022
# 11                  City                                           NEW YORK
# 12                 State                                                 NY
# 13             Code pays                                                 US
# 14          Country Name                           United States of America
# 15                Gender                                               Male
# 16         Client Source                                                NaN
# 17      Last Modified On                         2021-12-31 13:18:17.857000
# 18            Created On                         2021-02-12 04:50:21.513000
# 19                   NaN                                                NaN
# 20                   NaN                                                NaN
# 21                   NaN                                                NaN
# 22                   NaN                                                NaN
# 23                   NaN                                                NaN
# 24                   NaN                                                NaN
# 25                   NaN                                                NaN
# 26                   NaN                                                NaN
# 27                   NaN                                                NaN
# 28                   NaN                                                NaN
# 29                   NaN                                                NaN
# 30                   NaN                                                NaN
# 31                   NaN                                                NaN
# 32                   NaN                                                NaN
# 33                   NaN                                                NaN
# 34                   NaN                                                NaN
# 35                   NaN                                                NaN
# 36                   NaN                                                NaN
# 37                   NaN                                                NaN
# 38                   NaN                                                NaN
# 39                   NaN                                                NaN
# 40                   NaN                                                NaN
# 41                   NaN                                                NaN
# 42                   NaN                                                NaN
# 43                   NaN                                                NaN
# 44                   NaN                                                NaN
#
#                                            Unnamed: 6  Unnamed: 7  \
# 0                                                 NaN         NaN
# 1                                         Description         NaN
# 2                                          Contact ID         NaN
# 3                                              Status         NaN
# 4                                 Business Account ID         NaN
# 5                             Class ID of the contact         NaN
# 6                 Class Name given by the fundraisers         NaN
# 7                                                 NaN         NaN
# 8            Main fundraiser in charge of the contact         NaN
# 9          Second fundraiser in charge of the contact         NaN
# 10                         Postal Code of the Contact         NaN
# 11                                City of the Contact         NaN
# 12                               State of the Contact         NaN
# 13                                         Country ID         NaN
# 14                        Country Name of the Contact         NaN
# 15                                             Gender         NaN
# 16  HelloAsso is a website that allows individuals...         NaN
# 17                                   Last Modified On         NaN
# 18                                         Created On         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 30                                                NaN         NaN
# 31                                                NaN         NaN
# 32                                                NaN         NaN
# 33                                                NaN         NaN
# 34                                                NaN         NaN
# 35                                                NaN         NaN
# 36                                                NaN         NaN
# 37                                                NaN         NaN
# 38                                                NaN         NaN
# 39                                                NaN         NaN
# 40                                                NaN         NaN
# 41                                                NaN         NaN
# 42                                                NaN         NaN
# 43                                                NaN         NaN
# 44                                                NaN         NaN
#
#                     Invoice and Opportunities           Unnamed: 9  ...  \
# 0   Table of invoices linked to opportunities                  NaN  ...
# 1                                     Columns             Examples  ...
# 2                                        Type              Invoice  ...
# 3                              Reference Nbr.            FC0004608  ...
# 4                                    Customer               C06507  ...
# 5                                      Amount                 5000  ...
# 6                                        Date  2023-10-10 00:00:00  ...
# 7                              Opportunity ID               004504  ...
# 8                                         NaN                  NaN  ...
# 9                                         NaN                  NaN  ...
# 10                                        NaN                  NaN  ...
# 11                                        NaN                  NaN  ...
# 12                                        NaN                  NaN  ...
# 13                                        NaN                  NaN  ...
# 14                                        NaN                  NaN  ...
# 15                                        NaN                  NaN  ...
# 16                                        NaN                  NaN  ...
# 17                                        NaN                  NaN  ...
# 18                                        NaN                  NaN  ...
# 19                                        NaN                  NaN  ...
# 20                                        NaN                  NaN  ...
# 21                                        NaN                  NaN  ...
# 22                                        NaN                  NaN  ...
# 23                                        NaN                  NaN  ...
# 24                                        NaN                  NaN  ...
# 25                                        NaN                  NaN  ...
# 26                                        NaN                  NaN  ...
# 27                                        NaN                  NaN  ...
# 28                                        NaN                  NaN  ...
# 29                                        NaN                  NaN  ...
# 30                                        NaN                  NaN  ...
# 31                                        NaN                  NaN  ...
# 32                                        NaN                  NaN  ...
# 33                                        NaN                  NaN  ...
# 34                                        NaN                  NaN  ...
# 35                                        NaN                  NaN  ...
# 36                                        NaN                  NaN  ...
# 37                                        NaN                  NaN  ...
# 38                                        NaN                  NaN  ...
# 39                                        NaN                  NaN  ...
# 40                                        NaN                  NaN  ...
# 41                                        NaN                  NaN  ...
# 42                                        NaN                  NaN  ...
# 43                                        NaN                  NaN  ...
# 44                                        NaN                  NaN  ...
#
#                                           Unnamed: 14  Unnamed: 15  \
# 0                                                 NaN          NaN
# 1                                         Description          NaN
# 2                                      Opportunity ID          NaN
# 3                               Line Nbr. of the item          NaN
# 4                                             Item ID          NaN
# 5        Year in which the amount should be accounted          NaN
# 6                              Unit Price of the Item          NaN
# 7                                            Quantity          NaN
# 8                                                 UOM          NaN
# 9                                         Total Price          NaN
# 10                                           Currency          NaN
# 11                                    Discount Amount          NaN
# 12                                        Discount, %          NaN
# 13  Program specified in the agreement for the acc...          NaN
# 14                                          Free Item          NaN
# 15                                       Tax Category          NaN
# 16                                                NaN          NaN
# 17                                                NaN          NaN
# 18                                                NaN          NaN
# 19                                                NaN          NaN
# 20                                                NaN          NaN
# 21                                                NaN          NaN
# 22                                                NaN          NaN
# 23                                                NaN          NaN
# 24                                                NaN          NaN
# 25                                                NaN          NaN
# 26                                                NaN          NaN
# 27                                                NaN          NaN
# 28                                                NaN          NaN
# 29                                                NaN          NaN
# 30                                                NaN          NaN
# 31                                                NaN          NaN
# 32                                                NaN          NaN
# 33                                                NaN          NaN
# 34                                                NaN          NaN
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37                                                NaN          NaN
# 38                                                NaN          NaN
# 39                                                NaN          NaN
# 40                                                NaN          NaN
# 41                                                NaN          NaN
# 42                                                NaN          NaN
# 43                                                NaN          NaN
# 44                                                NaN          NaN
#
#          Non-Stock Items                                        Unnamed: 17  \
# 0   Items/Articles table                                                NaN
# 1                      4                                           Examples
# 2           Inventory ID                                            CAMP001
# 3         Description EN  Henri LACHMANN room (1/2 day), fully equipped:...
# 4          Posting Class                                             CAMPUS
# 5           Tax Category                                             TVA 20
# 6              Base Unit                                             DEMI J
# 7            Item Status                                             Active
# 8             Created On                         2021-02-12 02:58:56.990000
# 9       Last Modified On                         2022-08-23 13:01:01.627000
# 10         Default Price                                                126
# 11                   NaN                                                NaN
# 12                   NaN                                                NaN
# 13                   NaN                                                NaN
# 14                   NaN                                                NaN
# 15                   NaN                                                NaN
# 16                   NaN                                                NaN
# 17                   NaN                                                NaN
# 18                   NaN                                                NaN
# 19                   NaN                                                NaN
# 20                   NaN                                                NaN
# 21                   NaN                                                NaN
# 22                   NaN                                                NaN
# 23                   NaN                                                NaN
# 24                   NaN                                                NaN
# 25                   NaN                                                NaN
# 26                   NaN                                                NaN
# 27                   NaN                                                NaN
# 28                   NaN                                                NaN
# 29                   NaN                                                NaN
# 30                   NaN                                                NaN
# 31                   NaN                                                NaN
# 32                   NaN                                                NaN
# 33                   NaN                                                NaN
# 34                   NaN                                                NaN
# 35                   NaN                                                NaN
# 36                   NaN                                                NaN
# 37                   NaN                                                NaN
# 38                   NaN                                                NaN
# 39                   NaN                                                NaN
# 40                   NaN                                                NaN
# 41                   NaN                                                NaN
# 42                   NaN                                                NaN
# 43                   NaN                                                NaN
# 44                   NaN                                                NaN
#
#                                 Unnamed: 18  Unnamed: 19  \
# 0                                       NaN          NaN
# 1                               Description          NaN
# 2                                   Item ID          NaN
# 3                                 Item Name          NaN
# 4                         Class of the Item          NaN
# 5                              Tax Category          NaN
# 6                                 Base Unit          NaN
# 7                               Item Status          NaN
# 8                                Created On          NaN
# 9                          Last Modified On          NaN
# 10  Default Price at which we sell the item          NaN
# 11                                      NaN          NaN
# 12                                      NaN          NaN
# 13                                      NaN          NaN
# 14                                      NaN          NaN
# 15                                      NaN          NaN
# 16                                      NaN          NaN
# 17                                      NaN          NaN
# 18                                      NaN          NaN
# 19                                      NaN          NaN
# 20                                      NaN          NaN
# 21                                      NaN          NaN
# 22                                      NaN          NaN
# 23                                      NaN          NaN
# 24                                      NaN          NaN
# 25                                      NaN          NaN
# 26                                      NaN          NaN
# 27                                      NaN          NaN
# 28                                      NaN          NaN
# 29                                      NaN          NaN
# 30                                      NaN          NaN
# 31                                      NaN          NaN
# 32                                      NaN          NaN
# 33                                      NaN          NaN
# 34                                      NaN          NaN
# 35                                      NaN          NaN
# 36                                      NaN          NaN
# 37                                      NaN          NaN
# 38                                      NaN          NaN
# 39                                      NaN          NaN
# 40                                      NaN          NaN
# 41                                      NaN          NaN
# 42                                      NaN          NaN
# 43                                      NaN          NaN
# 44                                      NaN          NaN
#
#                                 Opportunities                  Unnamed: 21  \
# 0                         Opportunities table                          NaN
# 1                                     Columns                     Examples
# 2                              Opportunity ID                       006287
# 3                            Business Account                       C00833
# 4                                  Contact ID                        35524
# 5                        Estimated Close Date          2024-01-04 00:00:00
# 6                                      Status                          New
# 7                                       Stage                          Won
# 8                                 Probability                          200
# 9                            Estimated amount                        10000
# 10                            Amount received                          NaN
# 11                                 Difference                       -10000
# 12                                 Owner Name                           29
# 13                             Follow-up with                          NaN
# 14                                   Class ID                   PPRIV EVNT
# 15                                      Class  Private partnership - Event
# 16                                     Source                     Campaign
# 17                            Source Campaign                       000030
# 18                              Campaign Name            2023 - Gala Paris
# 19                          Programme financé                          NaN
# 20                            Action financée                          NaN
# 21                                  Agreement                          NaN
# 22            Signature date of the agreement                          NaN
# 23                      Agreement expiry date                          NaN
# 24             Duration of agreement (months)                          NaN
# 25  Deadline for submission of interim report                          NaN
# 26                      Final report deadline                          NaN
# 27                            Type de contrat                          NaN
# 28                        Type de financement                          NaN
# 29                                  Zone SDLV                          NaN
# 30                   Theorical payment date 1                          NaN
# 31                 Theorical payment amount 1                          NaN
# 32                   Theorical payment date 2                          NaN
# 33                 Theorical payment amount 2                          NaN
# 34                   Theorical payment date 3                          NaN
# 35                 Theorical payment amount 3                          NaN
# 36                   Theorical payment date 4                          NaN
# 37                 Theorical payment amount 4                          NaN
# 38                   Theorical payment date 5                          NaN
# 39                 Theorical payment amount 5                          NaN
# 40                                 Created On   2023-10-06 14:12:51.183000
# 41                         Last Modified Date   2023-10-06 14:14:33.290000
# 42                          Actual Close Date                          NaN
# 43                            Assignment Date   2023-10-06 14:11:50.747000
# 44                                  Branch ID                         SDLV
#
#                    Unnamed: 22  \
# 0                          NaN
# 1                     Examples
# 2                       005923
# 3                       C01406
# 4                          NaN
# 5          2023-08-30 00:00:00
# 6                          Won
# 7                          Won
# 8                          200
# 9                         5217
# 10                        5217
# 11                           0
# 12                          17
# 13                         NaN
# 14                        PPUB
# 15          Public partnership
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19            Séjours et Camps
# 20  Camp de vacances, Chabotte
# 21                        True
# 22         2023-07-27 00:00:00
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27        Convention opération
# 28              Fonctionnement
# 29                  Pole Paris
# 30         2023-08-15 00:00:00
# 31                        5217
# 32                         NaN
# 33                         NaN
# 34                         NaN
# 35                         NaN
# 36                         NaN
# 37                         NaN
# 38                         NaN
# 39                         NaN
# 40  2023-08-30 11:25:40.333000
# 41  2023-09-19 18:09:00.847000
# 42         2023-09-19 00:00:00
# 43  2023-08-30 11:21:49.867000
# 44                        SDLV
#
#                                           Unnamed: 23
# 0                                                 NaN
# 1                                         Description
# 2                                      Opportunity ID
# 3                                 Business Account ID
# 4                                          Contact ID
# 5   Estimated date by which we are supposed to hav...
# 6                           Status of the Opportunity
# 7    Stage of the opportunity given by the fundraiser
# 8   Probability (It looks like the data is not ver...
# 9                                    Estimated amount
# 10                            Amount received to date
# 11        Difference (Amount we should still receive)
# 12       Main fundraiser in charge of the opportunity
# 13     Second fundraiser in charge of the opportunity
# 14                        Class ID of the opportunity
# 15                      Class given by the fundraiser
# 16  If the opportuny is related to a specific campain
# 17                                 Source Campaign ID
# 18                                      Campaign Name
# 19  Program for which the business account/contact...
# 20  Action(s) for which the business account/conta...
# 21                              Is there an Agreement
# 22                    Signature date of the agreement
# 23                              Agreement expiry date
# 24                     Duration of agreement (months)
# 25          Deadline for submission of interim report
# 26                              Final report deadline
# 27              Type of contract for public donations
# 28                                  Type of financing
# 29  Zone for which the business account/contact ac...
# 30                           Theorical payment date 1
# 31                         Theorical payment amount 1
# 32                           Theorical payment date 2
# 33                         Theorical payment amount 2
# 34                           Theorical payment date 3
# 35                         Theorical payment amount 3
# 36                           Theorical payment date 4
# 37                         Theorical payment amount 4
# 38                           Theorical payment date 5
# 39                         Theorical payment amount 5
# 40                                         Created On
# 41                                 Last Modified Date
# 42                                  Actual Close Date
# 43                                    Assignment Date
# 44                     Branch ID (we have 2 branches)
#
# [45 rows x 24 columns]
